# %% [markdown]
# # Imports

# %%
import pandas as pd
from sklearn import set_config
from joblib import Memory
from sklearn.preprocessing import StandardScaler

import sys, os
sys.path.insert(0, os.path.abspath(".."))

from src. model_evaluation_with_pca_and_balancing import evaluate_model, get_model_constructors, get_balancing_methods, train_and_evaluate_models, pca_train_and_evaluate_models

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %% [markdown]
# # No warnings

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning

warnings.filterwarnings("ignore", category=UndefinedMetricWarning)
sys.stderr = open(os.devnull, 'w')

# %% [markdown]
# # Memory Configuration

# %%
print('Configuring memory...')
set_config(working_memory=12000)
memory = Memory(location='cachedir', verbose=0)
memory.clear(warn=False)
# Out:
# Configuring memory...

# %% [markdown]
# # Load Data

# %%
print('Loading data...')
x_train = pd.read_csv("../datasets/x_train_unb.csv")
x_test = pd.read_csv("../datasets/x_test_unb.csv")
y_train = pd.read_csv("../datasets/y_train_unb.csv").squeeze()
y_test = pd.read_csv("../datasets/y_test_unb.csv").squeeze()
# Out:
# Loading data...

# %% [markdown]
# # Scaling

# %%
scaler = StandardScaler()
X_train_scaled = x_train
X_test_scaled = x_test

# %% [markdown]
# # Model Setup

# %%
model_constructors = get_model_constructors(y_train)
balancing_methods = get_balancing_methods()

# %% [markdown]
# # Evaluation Without PCA

# %%
train_and_evaluate_models(X_train_scaled, y_train, X_test_scaled, y_test, model_constructors, balancing_methods)
# Out:
# === Model: LogisticRegression, No balancing ===
# Configuration: LogisticRegression, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === Model: SVM, No balancing ===
# Configuration: SVM, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === Model: GaussianNB, No balancing ===
# Configuration: GaussianNB, No balancing
# [[371  53]
#  [  8  18]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.92       424
#            1       0.25      0.69      0.37        26
#
#     accuracy                           0.86       450
#    macro avg       0.62      0.78      0.65       450
# weighted avg       0.94      0.86      0.89       450
#
# ------------------------------------------------------------
#
# === Model: MLP, No balancing ===
# Configuration: MLP, No balancing
# [[420   4]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.93       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.93      0.91       450
#
# ------------------------------------------------------------
#
# === Model: XGBoost, No balancing ===
# Configuration: XGBoost, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === Model: GradientBoosting, No balancing ===
# Configuration: GradientBoosting, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === Model: KNN, No balancing ===
# Configuration: KNN, No balancing
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === Model: LogisticRegression, Class weights ===
# Configuration: LogisticRegression, Class weights
# [[373  51]
#  [  6  20]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       424
#            1       0.28      0.77      0.41        26
#
#     accuracy                           0.87       450
#    macro avg       0.63      0.82      0.67       450
# weighted avg       0.94      0.87      0.90       450
#
# ------------------------------------------------------------
#
# === Model: SVM, Class weights ===
# Configuration: SVM, Class weights
# [[385  39]
#  [ 13  13]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94       424
#            1       0.25      0.50      0.33        26
#
#     accuracy                           0.88       450
#    macro avg       0.61      0.70      0.64       450
# weighted avg       0.93      0.88      0.90       450
#
# ------------------------------------------------------------
#
# === Model: GaussianNB, Class weights ===
# Configuration: GaussianNB, Class weights
# [[371  53]
#  [  8  18]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.92       424
#            1       0.25      0.69      0.37        26
#
#     accuracy                           0.86       450
#    macro avg       0.62      0.78      0.65       450
# weighted avg       0.94      0.86      0.89       450
#
# ------------------------------------------------------------
#
# === Model: MLP, Class weights ===
# Configuration: MLP, Class weights
# [[420   4]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.93       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.93      0.91       450
#
# ------------------------------------------------------------
#
# === Model: XGBoost, Class weights ===
# Configuration: XGBoost, Class weights
# [[411  13]
#  [ 24   2]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       424
#            1       0.13      0.08      0.10        26
#
#     accuracy                           0.92       450
#    macro avg       0.54      0.52      0.53       450
# weighted avg       0.90      0.92      0.91       450
#
# ------------------------------------------------------------
#
# === Model: GradientBoosting, Class weights ===
# Configuration: GradientBoosting, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === Model: KNN, Class weights ===
# Configuration: KNN, Class weights
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === Model: LogisticRegression, SMOTE ===
# Configuration: LogisticRegression, SMOTE
# [[400  24]
#  [ 19   7]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       424
#            1       0.23      0.27      0.25        26
#
#     accuracy                           0.90       450
#    macro avg       0.59      0.61      0.60       450
# weighted avg       0.91      0.90      0.91       450
#
# ------------------------------------------------------------
#
# === Model: SVM, SMOTE ===
# Configuration: SVM, SMOTE
# [[404  20]
#  [ 21   5]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       424
#            1       0.20      0.19      0.20        26
#
#     accuracy                           0.91       450
#    macro avg       0.58      0.57      0.57       450
# weighted avg       0.91      0.91      0.91       450
#
# ------------------------------------------------------------
#
# === Model: GaussianNB, SMOTE ===
# Configuration: GaussianNB, SMOTE
# [[289 135]
#  [  3  23]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.68      0.81       424
#            1       0.15      0.88      0.25        26
#
#     accuracy                           0.69       450
#    macro avg       0.57      0.78      0.53       450
# weighted avg       0.94      0.69      0.78       450
#
# ------------------------------------------------------------
#
# === Model: MLP, SMOTE ===
# Configuration: MLP, SMOTE
# [[407  17]
#  [ 21   5]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96       424
#            1       0.23      0.19      0.21        26
#
#     accuracy                           0.92       450
#    macro avg       0.59      0.58      0.58       450
# weighted avg       0.91      0.92      0.91       450
#
# ------------------------------------------------------------
#
# === Model: XGBoost, SMOTE ===
# Configuration: XGBoost, SMOTE
# [[398  26]
#  [ 20   6]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       424
#            1       0.19      0.23      0.21        26
#
#     accuracy                           0.90       450
#    macro avg       0.57      0.58      0.58       450
# weighted avg       0.91      0.90      0.90       450
#
# ------------------------------------------------------------
#
# === Model: GradientBoosting, SMOTE ===
# Configuration: GradientBoosting, SMOTE
# [[390  34]
#  [ 16  10]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       424
#            1       0.23      0.38      0.29        26
#
#     accuracy                           0.89       450
#    macro avg       0.59      0.65      0.61       450
# weighted avg       0.92      0.89      0.90       450
#
# ------------------------------------------------------------
#
# === Model: KNN, SMOTE ===
# Configuration: KNN, SMOTE
# [[389  35]
#  [ 19   7]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94       424
#            1       0.17      0.27      0.21        26
#
#     accuracy                           0.88       450
#    macro avg       0.56      0.59      0.57       450
# weighted avg       0.91      0.88      0.89       450
#
# ------------------------------------------------------------

# %% [markdown]
# # Evaluation With PCA - Principal Component Analysis

# %%
pca_train_and_evaluate_models(X_train_scaled, y_train, X_test_scaled, y_test, model_constructors, balancing_methods, range(5, 17))
# Out:
# ### PCA: 5 components ###
#
# === PCA=5, Model: LogisticRegression, No balancing ===
# Configuration: PCA=5, LogisticRegression, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: SVM, No balancing ===
# Configuration: PCA=5, SVM, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: GaussianNB, No balancing ===
# Configuration: PCA=5, GaussianNB, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: MLP, No balancing ===
# Configuration: PCA=5, MLP, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: XGBoost, No balancing ===
# Configuration: PCA=5, XGBoost, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: GradientBoosting, No balancing ===
# Configuration: PCA=5, GradientBoosting, No balancing
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: KNN, No balancing ===
# Configuration: PCA=5, KNN, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: LogisticRegression, Class weights ===
# Configuration: PCA=5, LogisticRegression, Class weights
# [[368  56]
#  [  8  18]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92       424
#            1       0.24      0.69      0.36        26
#
#     accuracy                           0.86       450
#    macro avg       0.61      0.78      0.64       450
# weighted avg       0.94      0.86      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: SVM, Class weights ===
# Configuration: PCA=5, SVM, Class weights
# [[360  64]
#  [  9  17]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91       424
#            1       0.21      0.65      0.32        26
#
#     accuracy                           0.84       450
#    macro avg       0.59      0.75      0.61       450
# weighted avg       0.93      0.84      0.87       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: GaussianNB, Class weights ===
# Configuration: PCA=5, GaussianNB, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: MLP, Class weights ===
# Configuration: PCA=5, MLP, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: XGBoost, Class weights ===
# Configuration: PCA=5, XGBoost, Class weights
# [[408  16]
#  [ 25   1]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       424
#            1       0.06      0.04      0.05        26
#
#     accuracy                           0.91       450
#    macro avg       0.50      0.50      0.50       450
# weighted avg       0.89      0.91      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: GradientBoosting, Class weights ===
# Configuration: PCA=5, GradientBoosting, Class weights
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: KNN, Class weights ===
# Configuration: PCA=5, KNN, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: LogisticRegression, SMOTE ===
# Configuration: PCA=5, LogisticRegression, SMOTE
# [[369  55]
#  [  8  18]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92       424
#            1       0.25      0.69      0.36        26
#
#     accuracy                           0.86       450
#    macro avg       0.61      0.78      0.64       450
# weighted avg       0.94      0.86      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: SVM, SMOTE ===
# Configuration: PCA=5, SVM, SMOTE
# [[364  60]
#  [  8  18]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.91       424
#            1       0.23      0.69      0.35        26
#
#     accuracy                           0.85       450
#    macro avg       0.60      0.78      0.63       450
# weighted avg       0.94      0.85      0.88       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: GaussianNB, SMOTE ===
# Configuration: PCA=5, GaussianNB, SMOTE
# [[354  70]
#  [  5  21]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.83      0.90       424
#            1       0.23      0.81      0.36        26
#
#     accuracy                           0.83       450
#    macro avg       0.61      0.82      0.63       450
# weighted avg       0.94      0.83      0.87       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: MLP, SMOTE ===
# Configuration: PCA=5, MLP, SMOTE
# [[386  38]
#  [ 15  11]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.94       424
#            1       0.22      0.42      0.29        26
#
#     accuracy                           0.88       450
#    macro avg       0.59      0.67      0.61       450
# weighted avg       0.92      0.88      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: XGBoost, SMOTE ===
# Configuration: PCA=5, XGBoost, SMOTE
# [[401  23]
#  [ 23   3]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       424
#            1       0.12      0.12      0.12        26
#
#     accuracy                           0.90       450
#    macro avg       0.53      0.53      0.53       450
# weighted avg       0.90      0.90      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: GradientBoosting, SMOTE ===
# Configuration: PCA=5, GradientBoosting, SMOTE
# [[382  42]
#  [ 11  15]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.94       424
#            1       0.26      0.58      0.36        26
#
#     accuracy                           0.88       450
#    macro avg       0.62      0.74      0.65       450
# weighted avg       0.93      0.88      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=5, Model: KNN, SMOTE ===
# Configuration: PCA=5, KNN, SMOTE
# [[383  41]
#  [ 16  10]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93       424
#            1       0.20      0.38      0.26        26
#
#     accuracy                           0.87       450
#    macro avg       0.58      0.64      0.60       450
# weighted avg       0.92      0.87      0.89       450
#
# ------------------------------------------------------------
#
# ### PCA: 6 components ###
#
# === PCA=6, Model: LogisticRegression, No balancing ===
# Configuration: PCA=6, LogisticRegression, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: SVM, No balancing ===
# Configuration: PCA=6, SVM, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: GaussianNB, No balancing ===
# Configuration: PCA=6, GaussianNB, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: MLP, No balancing ===
# Configuration: PCA=6, MLP, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: XGBoost, No balancing ===
# Configuration: PCA=6, XGBoost, No balancing
# [[422   2]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: GradientBoosting, No balancing ===
# Configuration: PCA=6, GradientBoosting, No balancing
# [[423   1]
#  [ 25   1]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.50      0.04      0.07        26
#
#     accuracy                           0.94       450
#    macro avg       0.72      0.52      0.52       450
# weighted avg       0.92      0.94      0.92       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: KNN, No balancing ===
# Configuration: PCA=6, KNN, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: LogisticRegression, Class weights ===
# Configuration: PCA=6, LogisticRegression, Class weights
# [[369  55]
#  [  8  18]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92       424
#            1       0.25      0.69      0.36        26
#
#     accuracy                           0.86       450
#    macro avg       0.61      0.78      0.64       450
# weighted avg       0.94      0.86      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: SVM, Class weights ===
# Configuration: PCA=6, SVM, Class weights
# [[359  65]
#  [  6  20]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91       424
#            1       0.24      0.77      0.36        26
#
#     accuracy                           0.84       450
#    macro avg       0.61      0.81      0.64       450
# weighted avg       0.94      0.84      0.88       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: GaussianNB, Class weights ===
# Configuration: PCA=6, GaussianNB, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: MLP, Class weights ===
# Configuration: PCA=6, MLP, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: XGBoost, Class weights ===
# Configuration: PCA=6, XGBoost, Class weights
# [[412  12]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.92       450
#    macro avg       0.47      0.49      0.48       450
# weighted avg       0.89      0.92      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: GradientBoosting, Class weights ===
# Configuration: PCA=6, GradientBoosting, Class weights
# [[423   1]
#  [ 25   1]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.50      0.04      0.07        26
#
#     accuracy                           0.94       450
#    macro avg       0.72      0.52      0.52       450
# weighted avg       0.92      0.94      0.92       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: KNN, Class weights ===
# Configuration: PCA=6, KNN, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: LogisticRegression, SMOTE ===
# Configuration: PCA=6, LogisticRegression, SMOTE
# [[370  54]
#  [  7  19]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92       424
#            1       0.26      0.73      0.38        26
#
#     accuracy                           0.86       450
#    macro avg       0.62      0.80      0.65       450
# weighted avg       0.94      0.86      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: SVM, SMOTE ===
# Configuration: PCA=6, SVM, SMOTE
# [[372  52]
#  [  8  18]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       424
#            1       0.26      0.69      0.38        26
#
#     accuracy                           0.87       450
#    macro avg       0.62      0.78      0.65       450
# weighted avg       0.94      0.87      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: GaussianNB, SMOTE ===
# Configuration: PCA=6, GaussianNB, SMOTE
# [[355  69]
#  [  6  20]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.84      0.90       424
#            1       0.22      0.77      0.35        26
#
#     accuracy                           0.83       450
#    macro avg       0.60      0.80      0.63       450
# weighted avg       0.94      0.83      0.87       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: MLP, SMOTE ===
# Configuration: PCA=6, MLP, SMOTE
# [[392  32]
#  [ 18   8]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       424
#            1       0.20      0.31      0.24        26
#
#     accuracy                           0.89       450
#    macro avg       0.58      0.62      0.59       450
# weighted avg       0.91      0.89      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: XGBoost, SMOTE ===
# Configuration: PCA=6, XGBoost, SMOTE
# [[400  24]
#  [ 22   4]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       424
#            1       0.14      0.15      0.15        26
#
#     accuracy                           0.90       450
#    macro avg       0.55      0.55      0.55       450
# weighted avg       0.90      0.90      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: GradientBoosting, SMOTE ===
# Configuration: PCA=6, GradientBoosting, SMOTE
# [[378  46]
#  [ 14  12]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.93       424
#            1       0.21      0.46      0.29        26
#
#     accuracy                           0.87       450
#    macro avg       0.59      0.68      0.61       450
# weighted avg       0.92      0.87      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=6, Model: KNN, SMOTE ===
# Configuration: PCA=6, KNN, SMOTE
# [[384  40]
#  [ 17   9]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93       424
#            1       0.18      0.35      0.24        26
#
#     accuracy                           0.87       450
#    macro avg       0.57      0.63      0.59       450
# weighted avg       0.91      0.87      0.89       450
#
# ------------------------------------------------------------
#
# ### PCA: 7 components ###
#
# === PCA=7, Model: LogisticRegression, No balancing ===
# Configuration: PCA=7, LogisticRegression, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: SVM, No balancing ===
# Configuration: PCA=7, SVM, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: GaussianNB, No balancing ===
# Configuration: PCA=7, GaussianNB, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: MLP, No balancing ===
# Configuration: PCA=7, MLP, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: XGBoost, No balancing ===
# Configuration: PCA=7, XGBoost, No balancing
# [[422   2]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: GradientBoosting, No balancing ===
# Configuration: PCA=7, GradientBoosting, No balancing
# [[423   1]
#  [ 25   1]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.50      0.04      0.07        26
#
#     accuracy                           0.94       450
#    macro avg       0.72      0.52      0.52       450
# weighted avg       0.92      0.94      0.92       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: KNN, No balancing ===
# Configuration: PCA=7, KNN, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: LogisticRegression, Class weights ===
# Configuration: PCA=7, LogisticRegression, Class weights
# [[369  55]
#  [  8  18]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92       424
#            1       0.25      0.69      0.36        26
#
#     accuracy                           0.86       450
#    macro avg       0.61      0.78      0.64       450
# weighted avg       0.94      0.86      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: SVM, Class weights ===
# Configuration: PCA=7, SVM, Class weights
# [[358  66]
#  [  7  19]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.84      0.91       424
#            1       0.22      0.73      0.34        26
#
#     accuracy                           0.84       450
#    macro avg       0.60      0.79      0.62       450
# weighted avg       0.94      0.84      0.87       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: GaussianNB, Class weights ===
# Configuration: PCA=7, GaussianNB, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: MLP, Class weights ===
# Configuration: PCA=7, MLP, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: XGBoost, Class weights ===
# Configuration: PCA=7, XGBoost, Class weights
# [[416   8]
#  [ 22   4]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       424
#            1       0.33      0.15      0.21        26
#
#     accuracy                           0.93       450
#    macro avg       0.64      0.57      0.59       450
# weighted avg       0.91      0.93      0.92       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: GradientBoosting, Class weights ===
# Configuration: PCA=7, GradientBoosting, Class weights
# [[423   1]
#  [ 25   1]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.50      0.04      0.07        26
#
#     accuracy                           0.94       450
#    macro avg       0.72      0.52      0.52       450
# weighted avg       0.92      0.94      0.92       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: KNN, Class weights ===
# Configuration: PCA=7, KNN, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: LogisticRegression, SMOTE ===
# Configuration: PCA=7, LogisticRegression, SMOTE
# [[373  51]
#  [  8  18]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       424
#            1       0.26      0.69      0.38        26
#
#     accuracy                           0.87       450
#    macro avg       0.62      0.79      0.65       450
# weighted avg       0.94      0.87      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: SVM, SMOTE ===
# Configuration: PCA=7, SVM, SMOTE
# [[374  50]
#  [  7  19]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       424
#            1       0.28      0.73      0.40        26
#
#     accuracy                           0.87       450
#    macro avg       0.63      0.81      0.66       450
# weighted avg       0.94      0.87      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: GaussianNB, SMOTE ===
# Configuration: PCA=7, GaussianNB, SMOTE
# [[352  72]
#  [  6  20]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.83      0.90       424
#            1       0.22      0.77      0.34        26
#
#     accuracy                           0.83       450
#    macro avg       0.60      0.80      0.62       450
# weighted avg       0.94      0.83      0.87       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: MLP, SMOTE ===
# Configuration: PCA=7, MLP, SMOTE
# [[397  27]
#  [ 18   8]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       424
#            1       0.23      0.31      0.26        26
#
#     accuracy                           0.90       450
#    macro avg       0.59      0.62      0.60       450
# weighted avg       0.91      0.90      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: XGBoost, SMOTE ===
# Configuration: PCA=7, XGBoost, SMOTE
# [[402  22]
#  [ 22   4]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       424
#            1       0.15      0.15      0.15        26
#
#     accuracy                           0.90       450
#    macro avg       0.55      0.55      0.55       450
# weighted avg       0.90      0.90      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: GradientBoosting, SMOTE ===
# Configuration: PCA=7, GradientBoosting, SMOTE
# [[381  43]
#  [ 12  14]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93       424
#            1       0.25      0.54      0.34        26
#
#     accuracy                           0.88       450
#    macro avg       0.61      0.72      0.64       450
# weighted avg       0.93      0.88      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=7, Model: KNN, SMOTE ===
# Configuration: PCA=7, KNN, SMOTE
# [[386  38]
#  [ 18   8]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93       424
#            1       0.17      0.31      0.22        26
#
#     accuracy                           0.88       450
#    macro avg       0.56      0.61      0.58       450
# weighted avg       0.91      0.88      0.89       450
#
# ------------------------------------------------------------
#
# ### PCA: 8 components ###
#
# === PCA=8, Model: LogisticRegression, No balancing ===
# Configuration: PCA=8, LogisticRegression, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: SVM, No balancing ===
# Configuration: PCA=8, SVM, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: GaussianNB, No balancing ===
# Configuration: PCA=8, GaussianNB, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: MLP, No balancing ===
# Configuration: PCA=8, MLP, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: XGBoost, No balancing ===
# Configuration: PCA=8, XGBoost, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: GradientBoosting, No balancing ===
# Configuration: PCA=8, GradientBoosting, No balancing
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: KNN, No balancing ===
# Configuration: PCA=8, KNN, No balancing
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: LogisticRegression, Class weights ===
# Configuration: PCA=8, LogisticRegression, Class weights
# [[372  52]
#  [  9  17]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.92       424
#            1       0.25      0.65      0.36        26
#
#     accuracy                           0.86       450
#    macro avg       0.61      0.77      0.64       450
# weighted avg       0.93      0.86      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: SVM, Class weights ===
# Configuration: PCA=8, SVM, Class weights
# [[371  53]
#  [  7  19]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       424
#            1       0.26      0.73      0.39        26
#
#     accuracy                           0.87       450
#    macro avg       0.62      0.80      0.66       450
# weighted avg       0.94      0.87      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: GaussianNB, Class weights ===
# Configuration: PCA=8, GaussianNB, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: MLP, Class weights ===
# Configuration: PCA=8, MLP, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: XGBoost, Class weights ===
# Configuration: PCA=8, XGBoost, Class weights
# [[412  12]
#  [ 24   2]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       424
#            1       0.14      0.08      0.10        26
#
#     accuracy                           0.92       450
#    macro avg       0.54      0.52      0.53       450
# weighted avg       0.90      0.92      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: GradientBoosting, Class weights ===
# Configuration: PCA=8, GradientBoosting, Class weights
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: KNN, Class weights ===
# Configuration: PCA=8, KNN, Class weights
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: LogisticRegression, SMOTE ===
# Configuration: PCA=8, LogisticRegression, SMOTE
# [[374  50]
#  [  8  18]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       424
#            1       0.26      0.69      0.38        26
#
#     accuracy                           0.87       450
#    macro avg       0.62      0.79      0.66       450
# weighted avg       0.94      0.87      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: SVM, SMOTE ===
# Configuration: PCA=8, SVM, SMOTE
# [[382  42]
#  [ 12  14]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93       424
#            1       0.25      0.54      0.34        26
#
#     accuracy                           0.88       450
#    macro avg       0.61      0.72      0.64       450
# weighted avg       0.93      0.88      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: GaussianNB, SMOTE ===
# Configuration: PCA=8, GaussianNB, SMOTE
# [[354  70]
#  [ 11  15]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.83      0.90       424
#            1       0.18      0.58      0.27        26
#
#     accuracy                           0.82       450
#    macro avg       0.57      0.71      0.58       450
# weighted avg       0.92      0.82      0.86       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: MLP, SMOTE ===
# Configuration: PCA=8, MLP, SMOTE
# [[402  22]
#  [ 19   7]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       424
#            1       0.24      0.27      0.25        26
#
#     accuracy                           0.91       450
#    macro avg       0.60      0.61      0.60       450
# weighted avg       0.91      0.91      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: XGBoost, SMOTE ===
# Configuration: PCA=8, XGBoost, SMOTE
# [[406  18]
#  [ 21   5]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       424
#            1       0.22      0.19      0.20        26
#
#     accuracy                           0.91       450
#    macro avg       0.58      0.57      0.58       450
# weighted avg       0.91      0.91      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: GradientBoosting, SMOTE ===
# Configuration: PCA=8, GradientBoosting, SMOTE
# [[384  40]
#  [ 14  12]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93       424
#            1       0.23      0.46      0.31        26
#
#     accuracy                           0.88       450
#    macro avg       0.60      0.68      0.62       450
# weighted avg       0.92      0.88      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=8, Model: KNN, SMOTE ===
# Configuration: PCA=8, KNN, SMOTE
# [[389  35]
#  [ 17   9]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       424
#            1       0.20      0.35      0.26        26
#
#     accuracy                           0.88       450
#    macro avg       0.58      0.63      0.60       450
# weighted avg       0.91      0.88      0.90       450
#
# ------------------------------------------------------------
#
# ### PCA: 9 components ###
#
# === PCA=9, Model: LogisticRegression, No balancing ===
# Configuration: PCA=9, LogisticRegression, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=9, Model: SVM, No balancing ===
# Configuration: PCA=9, SVM, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=9, Model: GaussianNB, No balancing ===
# Configuration: PCA=9, GaussianNB, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=9, Model: MLP, No balancing ===
# Configuration: PCA=9, MLP, No balancing
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=9, Model: XGBoost, No balancing ===
# Configuration: PCA=9, XGBoost, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=9, Model: GradientBoosting, No balancing ===
# Configuration: PCA=9, GradientBoosting, No balancing
# [[423   1]
#  [ 25   1]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.50      0.04      0.07        26
#
#     accuracy                           0.94       450
#    macro avg       0.72      0.52      0.52       450
# weighted avg       0.92      0.94      0.92       450
#
# ------------------------------------------------------------
#
# === PCA=9, Model: KNN, No balancing ===
# Configuration: PCA=9, KNN, No balancing
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=9, Model: LogisticRegression, Class weights ===
# Configuration: PCA=9, LogisticRegression, Class weights
# [[372  52]
#  [  9  17]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.92       424
#            1       0.25      0.65      0.36        26
#
#     accuracy                           0.86       450
#    macro avg       0.61      0.77      0.64       450
# weighted avg       0.93      0.86      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=9, Model: SVM, Class weights ===
# Configuration: PCA=9, SVM, Class weights
# [[369  55]
#  [  8  18]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92       424
#            1       0.25      0.69      0.36        26
#
#     accuracy                           0.86       450
#    macro avg       0.61      0.78      0.64       450
# weighted avg       0.94      0.86      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=9, Model: GaussianNB, Class weights ===
# Configuration: PCA=9, GaussianNB, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=9, Model: MLP, Class weights ===
# Configuration: PCA=9, MLP, Class weights
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=9, Model: XGBoost, Class weights ===
# Configuration: PCA=9, XGBoost, Class weights
# [[412  12]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.92       450
#    macro avg       0.47      0.49      0.48       450
# ...
# Configuration: PCA=15, MLP, Class weights
# [[419   5]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.93       450
#    macro avg       0.47      0.49      0.48       450
# weighted avg       0.89      0.93      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=15, Model: XGBoost, Class weights ===
# Configuration: PCA=15, XGBoost, Class weights
# [[416   8]
#  [ 25   1]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       424
#            1       0.11      0.04      0.06        26
#
#     accuracy                           0.93       450
#    macro avg       0.53      0.51      0.51       450
# weighted avg       0.90      0.93      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=15, Model: GradientBoosting, Class weights ===
# Configuration: PCA=15, GradientBoosting, Class weights
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=15, Model: KNN, Class weights ===
# Configuration: PCA=15, KNN, Class weights
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=15, Model: LogisticRegression, SMOTE ===
# Configuration: PCA=15, LogisticRegression, SMOTE
# [[377  47]
#  [  9  17]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93       424
#            1       0.27      0.65      0.38        26
#
#     accuracy                           0.88       450
#    macro avg       0.62      0.77      0.65       450
# weighted avg       0.94      0.88      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=15, Model: SVM, SMOTE ===
# Configuration: PCA=15, SVM, SMOTE
# [[397  27]
#  [ 18   8]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       424
#            1       0.23      0.31      0.26        26
#
#     accuracy                           0.90       450
#    macro avg       0.59      0.62      0.60       450
# weighted avg       0.91      0.90      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=15, Model: GaussianNB, SMOTE ===
# Configuration: PCA=15, GaussianNB, SMOTE
# [[365  59]
#  [  6  20]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.92       424
#            1       0.25      0.77      0.38        26
#
#     accuracy                           0.86       450
#    macro avg       0.62      0.82      0.65       450
# weighted avg       0.94      0.86      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=15, Model: MLP, SMOTE ===
# Configuration: PCA=15, MLP, SMOTE
# [[415   9]
#  [ 24   2]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       424
#            1       0.18      0.08      0.11        26
#
#     accuracy                           0.93       450
#    macro avg       0.56      0.53      0.53       450
# weighted avg       0.90      0.93      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=15, Model: XGBoost, SMOTE ===
# Configuration: PCA=15, XGBoost, SMOTE
# [[413  11]
#  [ 25   1]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       424
#            1       0.08      0.04      0.05        26
#
#     accuracy                           0.92       450
#    macro avg       0.51      0.51      0.51       450
# weighted avg       0.89      0.92      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=15, Model: GradientBoosting, SMOTE ===
# Configuration: PCA=15, GradientBoosting, SMOTE
# [[399  25]
#  [ 18   8]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       424
#            1       0.24      0.31      0.27        26
#
#     accuracy                           0.90       450
#    macro avg       0.60      0.62      0.61       450
# weighted avg       0.92      0.90      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=15, Model: KNN, SMOTE ===
# Configuration: PCA=15, KNN, SMOTE
# [[388  36]
#  [ 17   9]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       424
#            1       0.20      0.35      0.25        26
#
#     accuracy                           0.88       450
#    macro avg       0.58      0.63      0.59       450
# weighted avg       0.91      0.88      0.90       450
#
# ------------------------------------------------------------
#
# ### PCA: 16 components ###
#
# === PCA=16, Model: LogisticRegression, No balancing ===
# Configuration: PCA=16, LogisticRegression, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: SVM, No balancing ===
# Configuration: PCA=16, SVM, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: GaussianNB, No balancing ===
# Configuration: PCA=16, GaussianNB, No balancing
# [[403  21]
#  [ 16  10]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96       424
#            1       0.32      0.38      0.35        26
#
#     accuracy                           0.92       450
#    macro avg       0.64      0.67      0.65       450
# weighted avg       0.92      0.92      0.92       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: MLP, No balancing ===
# Configuration: PCA=16, MLP, No balancing
# [[421   3]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: XGBoost, No balancing ===
# Configuration: PCA=16, XGBoost, No balancing
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: GradientBoosting, No balancing ===
# Configuration: PCA=16, GradientBoosting, No balancing
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: KNN, No balancing ===
# Configuration: PCA=16, KNN, No balancing
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: LogisticRegression, Class weights ===
# Configuration: PCA=16, LogisticRegression, Class weights
# [[373  51]
#  [  6  20]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       424
#            1       0.28      0.77      0.41        26
#
#     accuracy                           0.87       450
#    macro avg       0.63      0.82      0.67       450
# weighted avg       0.94      0.87      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: SVM, Class weights ===
# Configuration: PCA=16, SVM, Class weights
# [[385  39]
#  [ 16  10]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93       424
#            1       0.20      0.38      0.27        26
#
#     accuracy                           0.88       450
#    macro avg       0.58      0.65      0.60       450
# weighted avg       0.92      0.88      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: GaussianNB, Class weights ===
# Configuration: PCA=16, GaussianNB, Class weights
# [[403  21]
#  [ 16  10]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96       424
#            1       0.32      0.38      0.35        26
#
#     accuracy                           0.92       450
#    macro avg       0.64      0.67      0.65       450
# weighted avg       0.92      0.92      0.92       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: MLP, Class weights ===
# Configuration: PCA=16, MLP, Class weights
# [[421   3]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: XGBoost, Class weights ===
# Configuration: PCA=16, XGBoost, Class weights
# [[416   8]
#  [ 25   1]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       424
#            1       0.11      0.04      0.06        26
#
#     accuracy                           0.93       450
#    macro avg       0.53      0.51      0.51       450
# weighted avg       0.90      0.93      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: GradientBoosting, Class weights ===
# Configuration: PCA=16, GradientBoosting, Class weights
# [[424   0]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.49       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: KNN, Class weights ===
# Configuration: PCA=16, KNN, Class weights
# [[423   1]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.94       450
#    macro avg       0.47      0.50      0.48       450
# weighted avg       0.89      0.94      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: LogisticRegression, SMOTE ===
# Configuration: PCA=16, LogisticRegression, SMOTE
# [[377  47]
#  [  9  17]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93       424
#            1       0.27      0.65      0.38        26
#
#     accuracy                           0.88       450
#    macro avg       0.62      0.77      0.65       450
# weighted avg       0.94      0.88      0.90       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: SVM, SMOTE ===
# Configuration: PCA=16, SVM, SMOTE
# [[397  27]
#  [ 18   8]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       424
#            1       0.23      0.31      0.26        26
#
#     accuracy                           0.90       450
#    macro avg       0.59      0.62      0.60       450
# weighted avg       0.91      0.90      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: GaussianNB, SMOTE ===
# Configuration: PCA=16, GaussianNB, SMOTE
# [[365  59]
#  [  6  20]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.92       424
#            1       0.25      0.77      0.38        26
#
#     accuracy                           0.86       450
#    macro avg       0.62      0.82      0.65       450
# weighted avg       0.94      0.86      0.89       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: MLP, SMOTE ===
# Configuration: PCA=16, MLP, SMOTE
# [[412  12]
#  [ 24   2]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       424
#            1       0.14      0.08      0.10        26
#
#     accuracy                           0.92       450
#    macro avg       0.54      0.52      0.53       450
# weighted avg       0.90      0.92      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: XGBoost, SMOTE ===
# Configuration: PCA=16, XGBoost, SMOTE
# [[417   7]
#  [ 26   0]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       424
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.93       450
#    macro avg       0.47      0.49      0.48       450
# weighted avg       0.89      0.93      0.91       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: GradientBoosting, SMOTE ===
# Configuration: PCA=16, GradientBoosting, SMOTE
# [[411  13]
#  [ 21   5]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       424
#            1       0.28      0.19      0.23        26
#
#     accuracy                           0.92       450
#    macro avg       0.61      0.58      0.59       450
# weighted avg       0.91      0.92      0.92       450
#
# ------------------------------------------------------------
#
# === PCA=16, Model: KNN, SMOTE ===
# Configuration: PCA=16, KNN, SMOTE
# [[388  36]
#  [ 17   9]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       424
#            1       0.20      0.35      0.25        26
#
#     accuracy                           0.88       450
#    macro avg       0.58      0.63      0.59       450
# weighted avg       0.91      0.88      0.90       450
#
# ------------------------------------------------------------
